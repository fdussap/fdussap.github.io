# %% [markdown]
# # Test de l'installation
#
# Selectionner la cellule ci-dessous, et executez-la avec `Maj + Entrée` (ou avec le bouton ▶︎ de la barre de commande).

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib, scipy

print("NumPy version :", np.__version__)
print("Matplotlib version :", matplotlib.__version__)
print("SciPy version :", scipy.__version__)

x = np.linspace(0, 2*np.pi, 100)
plt.plot(x, np.sin(x))
plt.title("Si vous voyez cette courbe, tout fonctionne !")
plt.show()

# %% [markdown]
# Pour arrêter Jupyter, aller dans **File > Shut down**.
